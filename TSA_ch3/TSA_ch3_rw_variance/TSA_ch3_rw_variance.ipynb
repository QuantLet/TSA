# %% [markdown]
# # TSA Chapter 3: Random Walk Variance Growth[![Open In Colab](https://colab.research.google.com/assets/colab-badge.svg)](https://colab.research.google.com/github/QuantLet/TSA/blob/main/TSA_ch3/TSA_ch3_rw_variance/TSA_ch3_rw_variance.ipynb)Random walk variance grows linearly: Var(Y_t) = t * sigma^2. Empirical vs theoretical variance from 1000 simulations.

# %%
# !pip install numpy pandas matplotlib statsmodels scipy -q

# %%
import osimport numpy as npimport pandas as pdimport matplotlib.pyplot as pltfrom statsmodels.tsa.stattools import acf, pacf, adfuller, kpssimport warningswarnings.filterwarnings('ignore')COLORS = {'blue': '#1A3A6E', 'red': '#DC3545', 'green': '#2E7D32', 'orange': '#E67E22', 'gray': '#666666', 'purple': '#8E44AD'}BLUE, RED, GREEN, ORANGE, GRAY, PURPLE = COLORS['blue'], COLORS['red'], COLORS['green'], COLORS['orange'], COLORS['gray'], COLORS['purple']plt.rcParams.update({    'figure.facecolor': 'none', 'axes.facecolor': 'none', 'savefig.facecolor': 'none',    'savefig.transparent': True, 'axes.spines.top': False, 'axes.spines.right': False,    'axes.grid': False, 'font.size': 10, 'axes.titlesize': 12, 'axes.labelsize': 10,    'xtick.labelsize': 9, 'ytick.labelsize': 9, 'legend.fontsize': 9, 'figure.dpi': 150,    'lines.linewidth': 1.2, 'axes.linewidth': 0.6, 'legend.facecolor': 'none',    'legend.framealpha': 0, 'legend.edgecolor': 'none',})np.random.seed(42)def save_chart(fig, name):    fig.savefig(f'{name}.pdf', bbox_inches='tight', transparent=True, dpi=150)    fig.savefig(f'{name}.png', bbox_inches='tight', transparent=True, dpi=150)    print(f'Saved: {name}')

# %%
# Random walk variance growth: Var(Y_t) = t * sigma^2n = 500n_sims = 1000# Simulate many random walksall_rw = np.cumsum(np.random.normal(0, 1, (n_sims, n)), axis=1)empirical_var = np.var(all_rw, axis=0)theoretical_var = np.arange(1, n + 1)fig, axes = plt.subplots(1, 2, figsize=(10, 4))# Left: Multiple random walk pathsfor i in range(10):    eps = np.random.normal(0, 1, n)    rw = np.cumsum(eps)    axes[0].plot(rw, linewidth=0.8, alpha=0.7)axes[0].axhline(y=0, color='black', linestyle='--', linewidth=0.5)axes[0].set_title('Random Walk Paths', fontweight='bold')axes[0].set_xlabel('Time (t)')axes[0].set_ylabel(r'$Y_t$')# Right: Variance growthaxes[1].plot(empirical_var, color=BLUE, linewidth=1.5, label='Empirical variance')axes[1].plot(theoretical_var, color=RED, linewidth=1.5, linestyle='--',             label=r'Theoretical: $t \cdot \sigma^2$')axes[1].set_title(r'Variance Growth: $\mathrm{Var}(Y_t) = t\sigma^2$', fontweight='bold')axes[1].set_xlabel('Time (t)')axes[1].set_ylabel('Variance')axes[1].legend(loc='upper center', bbox_to_anchor=(0.5, -0.18), ncol=2, frameon=False)plt.tight_layout()save_chart(fig, 'sem3_rw_variance')plt.show()
